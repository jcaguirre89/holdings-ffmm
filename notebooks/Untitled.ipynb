# %%
import pandas as pd

# %%
df = pd.read_csv('../data/holdings-2018-2019.csv')

# %%
df.head()
# Out:
#    run_fondo         nombre_fondo   nemotecnico  rut_emisor  \
# 0       8011  VISION MONEY MARKET  SNTANN050618  96667560.0
# 1       8011  VISION MONEY MARKET  FNEST-070218  97030000.0
# 2       8011  VISION MONEY MARKET  FNEST-070218  97030000.0
# 3       8011  VISION MONEY MARKET  FNEST-070218  97030000.0
# 4       8011  VISION MONEY MARKET  FNEST-070218  97030000.0
#
#   digito_verificador_rut_emisor pais_emisor tipo_instrumento  \
# 0                             8          CL               PE
# 1                             7          CL              DPC
# 2                             7          CL              DPC
# 3                             7          CL              DPC
# 4                             7          CL              DPC
#
#   fecha_vencimiento_instrumento  situacion_instrumento clasificacion_riesgo  \
# 0                    05/06/2018                      1                  N-1
# 1                    07/02/2018                      1                  N-1
# ...

# %%
df.iloc[0]
# Out:
# run_fondo                                         8011
# nombre_fondo                       VISION MONEY MARKET
# nemotecnico                               SNTANN050618
# rut_emisor                                 9.66676e+07
# digito_verificador_rut_emisor                        8
# pais_emisor                                         CL
# tipo_instrumento                                    PE
# fecha_vencimiento_instrumento               05/06/2018
# situacion_instrumento                                1
# clasificacion_riesgo                               N-1
# codigo_grupo_empresarial                           119
# cantidad_unidades                                1e+08
# tipo_unidades                                       $$
# TIR                                                0.3
# valor_par                                          NaN
# valor_relevante                                    NaN
# codigo_valorizacion                                  1
# ...

# %%
df.sample(20)
# Out:
#         run_fondo          nombre_fondo   nemotecnico  rut_emisor  \
# 688985       8315    AHORRO CORPORATIVO    COR21D0106  97023000.0
# 493393       8910   BANKING CONSERVADOR  FNCHI-290519  97004000.0
# 225461       8935         BICE COLOMBIA          INAR         NaN
# 542069       9190   ESTRATEGIA MODERADA    CFMLVEUROL      9027.0
# 75008        8525   ESTRATEGIA MODERADA    BBNS-Q0513  97018000.0
# 263833       8676     RENTA BONOS CHILE       BELME-D  90320000.0
# 221929       8824   GESTION ESTRATEGICA       BCENC-N  93834000.0
# 848576       9597  FONDO DEUDA MED P UF    UBBV-A1203  97018000.0
# 505451       8035                AHORRO    BCORAI0710  97023000.0
# 715380       9655   DEUDA INTERNACIONAL    VECMHIH LX         NaN
# 66539        8316  PROTECCION BANCOESTA  FNCOR-040718  97023000.0
# 800970       9228     FM BCI GGD AHORRO    BBNS-V0514  97018000.0
# 19726        8316  PROTECCION BANCOESTA    BBIC510214  97080000.0
# ...

# %%
df.set_index('run_fondo', inplace=True)

# %%
run_fondo = 8707
df_global = df.loc[run_fondo]

# %%
month = 8
year = 2019
df_global_latest = df_global.loc[(df_global['month'] == month) & (df_global['year'] == year)]

# %%
df_global_latest
# Out:
#                nombre_fondo        nemotecnico  rut_emisor  \
# run_fondo
# 8707       SELECCION GLOBAL     SLQD US EQUITY         NaN
# 8707       SELECCION GLOBAL      EWU US EQUITY         NaN
# 8707       SELECCION GLOBAL      EWW US EQUITY         NaN
# 8707       SELECCION GLOBAL      EWY US EQUITY         NaN
# 8707       SELECCION GLOBAL      EWZ US EQUITY         NaN
# 8707       SELECCION GLOBAL      EZA US EQUITY         NaN
# 8707       SELECCION GLOBAL      EZU US EQUITY         NaN
# 8707       SELECCION GLOBAL  FLEEUEC LX EQUITY         NaN
# 8707       SELECCION GLOBAL      GXG US EQUITY         NaN
# 8707       SELECCION GLOBAL     HEZU US EQUITY         NaN
# 8707       SELECCION GLOBAL  HHJPNIA LX EQUITY         NaN
# 8707       SELECCION GLOBAL      EWS US EQUITY         NaN
# 8707       SELECCION GLOBAL      IEF US EQUITY         NaN
# 8707       SELECCION GLOBAL      ILF US EQUITY         NaN
# 8707       SELECCION GLOBAL     INDA US EQUITY         NaN
# ...
