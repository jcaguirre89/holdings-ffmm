# %%
import pandas as pd
import dask as dd

# %%
df = pd.read_csv('../data/holdings.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  run_fondo     nombre_fondo nemotecnico  rut_emisor  \
# 0           0       8001  CAPITALISA-ACC.  BSANTANDER  97036000.0
# 1          19       8001  CAPITALISA-ACC.     VAPORES  90160000.0
# 2          18       8001  CAPITALISA-ACC.       SQM-B  93007000.0
# 3          17       8001  CAPITALISA-ACC.      RIPLEY  99579730.0
# 4          15       8001  CAPITALISA-ACC.      MASISA  96802690.0
#
#   digito_verificador_rut_emisor pais_emisor tipo_instrumento  \
# 0                             K          CL              ACC
# 1                             7          CL              ACC
# 2                             9          CL              ACC
# 3                             5          CL              ACC
# 4                             9          CL              ACC
#
#   fecha_vencimiento_instrumento  situacion_instrumento  ...  \
# 0                           NaN                    1.0  ...
# 1                           NaN                    1.0  ...
# ...

# %%
df.iloc[0]
# Out:
# Unnamed: 0                                       0
# run_fondo                                     8001
# nombre_fondo                       CAPITALISA-ACC.
# nemotecnico                             BSANTANDER
# rut_emisor                              9.7036e+07
# digito_verificador_rut_emisor                    K
# pais_emisor                                     CL
# tipo_instrumento                               ACC
# fecha_vencimiento_instrumento                  NaN
# situacion_instrumento                            1
# clasificacion_riesgo                           N-2
# codigo_grupo_empresarial                        14
# cantidad_unidades                      6.67612e+06
# tipo_unidades                                   $$
# TIR                                            NaN
# valor_par                                      NaN
# valor_relevante                              21.82
# codigo_valorizacion                              3
# ...
